# %% [markdown]
# ## Can you create a random sample of 500 rows from that dataset?

# %%
import pandas as pd
import numpy as np
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:500]).head(20)
# Out:
#          fname      lname  gender  age  exercise  hours  grade  \
# 151     Maggie       Rich  female   19         2     11   77.3
# 1756  Colorado   Sullivan    male   19         1     10   76.2
# 977    Imogene     Berger  female   19         4     10   81.3
# 1061       May   Sandoval  female   16         4      7   79.5
# 543      Kuame     Conrad    male   18         3     14   92.6
# 516      Rahim     Weaver    male   19         4     12   92.9
# 1041    Dexter       Horn    male   16         2     10   88.8
# 863      Cally    Pearson  female   17         1     11   88.2
# 608     Connor      Huber    male   19         4      8   84.9
# 1718      Nita   Castillo  female   19         5     10   92.1
# 1254     Adara  Fernandez  female   15         5     13   98.5
# 1286     Shana     Conner  female   16         2     12   81.5
# 1394       Gil      Duran    male   16         1     13   83.8
# 1812    Cooper     Thomas    male   16         2     12   80.1
# ...
